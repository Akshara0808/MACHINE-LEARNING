# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\MIKKY\\Downloads\\vgsales.csv.zip')#no need to upload as all are in same folder
df
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.values # an array of size df.shape
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
import pandas as pd


music_data = pd.read_csv('C:\\Users\\MIKKY\\Downloads\\music.csv')#after pasting the path there must be 2 slashes (//)
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
from sklearn.tree import DecisionTreeClassifier
import joblib
x = music_data.drop(columns = ['genre']) #remove genre col
y = music_data['genre']
model = DecisionTreeClassifier()
model.fit(x, y)
# Out:
# DecisionTreeClassifier()

# %%
#joblib.dump(model, 'music-rec.joblib') #store the trained model in teh file
model = joblib.load('music-rec.joblib')#store the trained model in teh file
predictions= model.predict( [[21, 1], [22,0]])
predictions
# Out:
# C:\Users\MIKKY\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
#accuracy
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

x = music_data.drop(columns = ['genre']) #remove genre col
y = music_data['genre']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)#20 percent data for testing 
#if test_size is more and train_data is less, accuracy dec
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)

sc = accuracy_score(y_test, predictions)
sc
# Out:
# 0.2

# %%
#for autocomplete 
# %config IPCompleter.greedy=True

# %%
from sklearn import tree

tree.export_graphviz(model, out_file='music_recommender.dot' , feature_names = ['age', 'gender'], \
                     class_names = sorted(y.unique()), # it stores type of music (output) like hiphop, dance, classical etc\
                    label = 'all', rounded = True,filled = True)
